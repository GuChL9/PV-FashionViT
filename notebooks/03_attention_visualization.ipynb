# %% [markdown]
# # Attention Rollout 可视化
# 主图自动筛选 ViT-AbsPos 错、HybridConv-ViT 对的四角案例；每个案例并排比较两个模型的 attention rollout。注意力图仅作模型行为的辅助解释，不能直接等同于因果证据。

# %%
# %cd ..
# %run src/visualize_attention_comparison.py

# %%
# %run src/visualize_attention.py --config configs/seeds/hybrid_vit_s42.yaml --checkpoint outputs/hybrid_vit_cpu_s42/checkpoints/best.pt --mode grid_shift --dx 18 --dy 18
